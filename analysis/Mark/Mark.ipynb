# %% [markdown]
# <h1><i>Entry</i> Data</h1>

# %% [markdown]
# <hr>
#
# <b>Project Milestone 2</b>

# %% [markdown]
# <a href="https://www.kaggle.com/prasoonkottarathil/apple-lifetime-stocks-dataset" >Link to Data</a>

# %% [markdown]
# <h3>Accessing EDA from 'project_functions'</h3>

# %%
from project_functions.ipynb import EDA

df2 = EDA(csvPath)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-228668cebb89> in <module>
# ----> 1 from project_functions.ipynb import EDA
#       2
#       3 df2 = EDA(csvPath)
#       4 df2.head()
#
# ModuleNotFoundError: No module named 'project_functions'

# %% [markdown]
# <h3>Barplot of the first 5 values</h3>

# %% [markdown]
# Motive: the goal of plotting this data was to see which years had the all-time high. Using these years, we could use the 2020
# data to estimate if 2020 would be among the best years. Note: This data is used strictly with no external motives in mind. For example, we cannot conclude that the global pandemic will cause 2020 to not be among these years as we are not looking at external variables.

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.barplot(x="Date", y="High", data=tips)

# %% [markdown]
# Description: The following graphs are differentiated by the plot type. These plots are used to gain a further understanding of
# data visualization and how the best type fits the data.

# %% [markdown]
# <h3> Scatterplot of the same data</h3>

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.scatterplot(x="Date", y="High", data=tips)

# %% [markdown]
# Description: The following graphs are differentiated by the plot type. These plots are used to gain a further understanding of
# data visualization and how the best type fits the data.

# %% [markdown]
# <h3>Boxplot</h3>

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.boxplot(x="Date", y="High", data=tips)

# %% [markdown]
# Description: The following graphs are differentiated by the plot type. These plots are used to gain a further understanding of
# data visualization and how the best type fits the data.

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.barplot(x="Date", y="High", data=tips)

# %%
import pandas as pd

path = "../../data/raw/AAPL.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data);
df.drop(['Open', 'Low', 'Close','Adj Close', 'Volume'], axis=1).to_csv('data_Date_High.csv')
