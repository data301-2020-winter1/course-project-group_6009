# %% [markdown]
# **IMPORTED PANDAS AND PUT CSV INTO DATAFRAME**
# --
# *I also did df.head() to display the head of the CSV*

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.style.use('bmh')

# %%
df = pd.read_csv("../../data/raw/AAPL.csv")
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9818  2019-11-19  267.899994  268.000000  265.390015  266.290009  266.290009
# 9819  2019-11-20  265.540009  266.079987  260.399994  263.190002  263.190002
# 9820  2019-11-21  263.690002  264.010010  261.179993  262.010010  262.010010
# 9821  2019-11-22  262.589996  263.179993  260.839996  261.779999  261.779999
# 9822  2019-11-25  262.709991  266.440002  262.519989  266.369995  266.369995
#
#           Volume
# 9818  19041800.0
# 9819  26558600.0
# 9820  30348800.0
# 9821  16331300.0
# 9822  21005100.0

# %% [markdown]
# **My EDA**
# --

# %% [markdown]
# *Dropping columns*

# %%
df.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'], inplace=True)

df.tail()
# Out:
#             Date       Close
# 9818  2019-11-19  266.290009
# 9819  2019-11-20  263.190002
# 9820  2019-11-21  262.010010
# 9821  2019-11-22  261.779999
# 9822  2019-11-25  266.369995

# %% [markdown]
# *Dropping the Null values*

# %%
df.dropna(inplace=True)

# %% [markdown]
# *Checking to see if there are null values*

# %%
df.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %% [markdown]
# *Visualizing the closing price history*

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.show()
