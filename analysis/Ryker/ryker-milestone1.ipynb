# %% [markdown]
# **My EDA**
# --

# %%
import pandas as pd
import seaborn as sns

csvPath = "../../data/raw/AAPL.csv"


def EDA(csvPath):
    df = pd.read_csv("csvPath").drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'], implace = True).dropna(inplace=True).isnull().sum()
    
    return df

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.barplot(x="Date", y="High", data=tips)

# %% [markdown]
# **Motive**
#
# The motive of this barplot is to sort the "High" values, to help better answer our research question.

# %%
import pandas as pd
import seaborn as sns
csvPath = "../../data/raw/AAPL.csv"
sns.set_theme(style="whitegrid")
tips = pd.read_csv(csvPath).sort_values("High", ascending = True).head(5)
ax = sns.boxplot(x="Date", y="High", data=tips)

# %% [markdown]
# Description: The following graphs are differentiated by the plot type. These plots are used to further our understaning of the data and help better our visualization of the data.
